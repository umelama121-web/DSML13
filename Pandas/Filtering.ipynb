# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("titanic_data.csv")
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Conditional Based Filtering

# %%
mask = titanic_df.Fare > 100
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
fare_100 = titanic_df[mask]
fare_100
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
fare_100.shape
# Out:
# (53, 12)

# %% [markdown]
# Out of 891 passenger, only 53 passenger paid more than 100 $ fare

# %%
female_fare_100 = fare_100[fare_100.Sex == "female"]
female_fare_100
# Out:
#      PassengerId  Survived  Pclass  \
# 31            32         1       1
# 88            89         1       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 380          381         1       1
# 393          394         1       1
# 435          436         1       1
# 498          499         0       1
# 537          538         1       1
# 581          582         1       1
# 609          610         1       1
# ...

# %%
female_fare_100.shape
# Out:
# (34, 12)

# %%
print(f"Out of 53 : {round((34/53) * 100, 2)} % were female passenger")
#Why nearly 65% of the highest paying passenger were female in 1912 ?
# Out:
# Out of 53 : 64.15 % were female passenger

# %%
fare_100_male = fare_100[fare_100.Sex== "male"]
fare_100_male
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 118          119         0       1
# 305          306         1       1
# 332          333         0       1
# 373          374         0       1
# 377          378         0       1
# 390          391         1       1
# 438          439         0       1
# 505          506         0       1
# 527          528         0       1
# 544          545         0       1
# 550          551         1       1
# 557          558         0       1
# 659          660         0       1
# 660          661         1       1
# 679          680         1       1
# 698          699         0       1
# 737          738         1       1
# 802          803         1       1
#
#                                            Name   Sex    Age  SibSp  Parch  \
# 27               Fortune, Mr. Charles Alexander  male  19.00      3      2
# 118                    Baxter, Mr. Quigg Edmond  male  24.00      0      1
# ...

# %%
fare_100_male.shape
# Out:
# (19, 12)

# %%
fare_100_male = titanic_df [
    (titanic_df.Fare > 100) & (titanic_df.Sex == "male")
]

fare_100_male.shape
# Out:
# (19, 12)

# %%
print(f"out of 53 : {round((19/53) * 100, 2)} % were Male passenger")
# Out:
# out of 53 : 35.85 % were Male passenger

# %%
survival_highclass = titanic_df[
    (titanic_df.Survived == 1) & (titanic_df.Pclass == 1)
]
survival_highclass
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
survival_highclass.shape
# Out:
# (136, 12)

# %%
print(f"Among all the passenger, {round((136/891) * 100, 2)} % were highclass pessesnger who survived ")
# Out:
# Among all the passenger, 15.26 % were highclass pessesnger who survived
