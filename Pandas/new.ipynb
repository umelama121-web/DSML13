# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/10.0 MB 10.7 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/10.0 MB 10.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/10.0 MB 9.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/10.0 MB 10.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.4/10.0 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 9.6 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.6 MB 8.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/12.6 MB 8.2 MB/s eta 0:00:02
#    -------------- ------------------------- 4.5/12.6 MB 8.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.6 MB 6.5 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
### Creating Dataframe
data = {
    "name" : ["Bob", "Arman", "Charls", "John"],
    "age" : [23,34,30,21]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#      name  age
# 0     Bob   23
# 1   Arman   34
# 2  Charls   30
# 3    John   21

# %%
### Reading Data From Files

# %%
titanic_df = pd.read_csv("titanic_data.csv", delimiter = ",")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
json_df = pd.read_json("users.json")
json_df
# Out:
#      id             name  is_active                     roles premium_since
# 0   101    Alice Johnson       True           [admin, editor]           NaN
# 1   102        Bob Smith       True                  [viewer]    2024-03-15
# 2   103    Carlos Mendez      False                  [editor]           NaN
# 3   104     Diana Prince       True  [admin, billing_manager]    2023-11-01
# 4   105      Evan Wright       True     [viewer, contributor]    2025-01-10
# 5   106  Fiona Gallagher      False                  [viewer]           NaN
# 6   107      George Chen       True       [editor, moderator]    2024-08-22
# 7   108    Hannah Abbott       True             [contributor]           NaN
# 8   109      Ian Malcolm       True                   [admin]    2022-06-30
# 9   110    Julia Roberts      False                  [viewer]    2023-04-12
# 10  111      Kevin Bacon       True        [editor, reviewer]    2025-05-18
# ...

# %%
type(json_df)
# Out:
# pandas.DataFrame

# %%
# Accessing Data

# %%
#Sneak peak
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Reading of column
#either
#name = titanic_df["Name"] -> mostely usefull
#or
name = titanic_df.Name #-> Limited
print(name)
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %%
type(name)
# Out:
# pandas.Series

# %%
name_age = titanic_df[["Name", 'Age']]
name_age
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
type(name_age)
# Out:
# pandas.DataFrame

# %%
#Reading Rows
second_row = titanic_df.loc[2]

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(second_row)
# Out:
# pandas.Series

# %%
#Basci properties
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
titanic_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
