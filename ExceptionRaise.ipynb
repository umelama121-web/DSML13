# %%
number = 56.33

if isinstance(number, int):
    print(f"Square root : {number**0.5}")
else:
    raise TypeError(f"value shoulf be int , not {type(number)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       2
#       3 if isinstance(number, int):
#       4     print(f"Square root : {number**0.5}")
#       5 else:
# ----> 6     raise TypeError(f"value shoulf be int , not {type(number)}")
#
# TypeError: value shoulf be int , not <class 'float'>

# %%
def divide(x, y):
    if y == 0:
        raise ValueError("Divisor should not be in zero")
    return x / y

divide(4,0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       2     if y == 0:
#       3         raise ValueError("Divisor should not be in zero")
#       4     return x / y
#       5
# ----> 6 divide(4,0)
#
# Cell In[2], line 3, in divide(x, y)
#       1 def divide(x, y):
#       2     if y == 0:
# ----> 3         raise ValueError("Divisor should not be in zero")
#       4     return x / y
#
# ValueError: Divisor should not be in zero

# %%
#User-define Excepttion



class InvalidAgeException(Exception):
    """Raise whrn input age is less than 18"""
    pass

raise InvalidAgeException
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeException                       Traceback (most recent call last)
# Cell In[6], line 9
#       5 class InvalidAgeException(Exception):
#       6     """Raise whrn input age is less than 18"""
#       7     pass
#       8
# ----> 9 raise InvalidAgeException
#
# InvalidAgeException:

# %%
def check_customer(customer_id):
    #somethoing 

    age = 21
    if "Liquior":
        if age >= 18:
            print("Good to go")
        else:
            raise InvalidAgeException("Must be an adult to purchase Liquire, age > 18")

check_customer(9856)
# Out:
# Good to go

# %%
#ATM
class InsufficientBalance(Exception):
    """Exception for insufficient balance"""
    pass

balance = 2500
def get_cash(withdraw_amount):
    if balance >= withdraw_amount:
        print("Withdrawn Sucessfill.")
        return f"New Balance {balance - withdraw_amount}"
    else:
        raise InsufficientBalance("Insufficient Balance")

get_cash(2000)
# Out:
# Withdrawn Sucessfill.
# 'New Balance 500'

# %%
#raise

try:
    x = 10 / 0
except ZeroDivisionError:
    print("Something went wrong")
    raise
# Out:
# Something went wrong
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 5
#       1 try:
#       2     x = 10 / 0
#       3 except ZeroDivisionError:
#       4     print("Something went wrong")
# ----> 5     raise
#
# ZeroDivisionError: division by zero
